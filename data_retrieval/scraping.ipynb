# %%
from kochwiki_scraper import scrape_all

# %%
scrape_all()
# Out:
# ...
# Scraping Namespace: rezepte (ID: 0)
# ...
#   Fetching pages... (so far: 0)
#   Fetching pages... (so far: 50)
#   Fetching pages... (so far: 100)
#   Fetching pages... (so far: 150)
#   Fetching pages... (so far: 200)
#   Fetching pages... (so far: 250)
#   Fetching pages... (so far: 300)
#   Fetching pages... (so far: 350)
#   Fetching pages... (so far: 400)
#   Fetching pages... (so far: 450)
#   Fetching pages... (so far: 500)
#   Fetching pages... (so far: 550)
#   Fetching pages... (so far: 600)
#   Fetching pages... (so far: 650)
#   Fetching pages... (so far: 700)
#   Fetching pages... (so far: 750)
#   Fetching pages... (so far: 800)
#   Fetching pages... (so far: 850)
#   Fetching pages... (so far: 900)
#   Fetching pages... (so far: 950)
#   Fetching pages... (so far: 1000)
#   Fetching pages... (so far: 1050)
#   Fetching pages... (so far: 1100)
#   Fetching pages... (so far: 1150)
#   Fetching pages... (so far: 1200)
#   Fetching pages... (so far: 1250)
# ...

# %%
from kochwiki_parser import parse_all_recipes, parse_all_zutaten

recipes = parse_all_recipes(
    "kochwiki_data/rezepte.json",
    "kochwiki_data/rezepte_parsed.json"
)

zutaten = parse_all_zutaten(
    "kochwiki_data/zutaten.json",
    "kochwiki_data/zutaten_parsed.json"
)
# Out:
# Lade kochwiki_data/rezepte.json...
# 14133 recipes loaded. Start Parsing...
#   [500/14133] processed...
#   [1000/14133] processed...
#   [1500/14133] processed...
#   [2000/14133] processed...
#   [2500/14133] processed...
#   [3000/14133] processed...
#   [3500/14133] processed...
#   [4000/14133] processed...
#   [4500/14133] processed...
#   [5000/14133] processed...
#   [5500/14133] processed...
#   [6000/14133] processed...
#   [6500/14133] processed...
#   [7000/14133] processed...
#   [7500/14133] processed...
#   [8000/14133] processed...
#   [8500/14133] processed...
#   [9000/14133] processed...
#   [9500/14133] processed...
#   [10000/14133] processed...
#   [10500/14133] processed...
#   [11000/14133] processed...
#   [11500/14133] processed...
#   [12000/14133] processed...
#   [12500/14133] processed...
#   [13000/14133] processed...
#   [13500/14133] processed...
#   [14000/14133] processed...
#
# ✓ 14133 recipes successfully parsed
# ✗ 0 Errors
# ...
