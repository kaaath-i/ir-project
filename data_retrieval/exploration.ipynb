# %%
import json

with open("kochwiki_data/rezepte_parsed.json", "r") as f:
    recipes = json.load(f)

with open("kochwiki_data/zutaten_parsed.json", "r") as f:
    zutaten = json.load(f)

print(f"Recipes: {len(recipes)}")
print(f"Ingredients: {len(zutaten)}")

# Ein paar Titel anschauen
print("\nFirst 10 Recipes:")
for r in recipes[:10]:
    print(f"  - {r['title']}")

print(f"\nFirst 10 Ingredients:")
for z in zutaten[:10]:
    print(f"  - {z['name']}")
# Out:
# Recipes: 14133
# Ingredients: 3981
#
# First 10 Recipes:
#   - "Krömpele"-Suppe
#   - 123 Teig
#   - 19th Green
#   - 1 2 3 Teig
#   - 2000 Miles away
#   - 43 Coco
#   - 43 Don Juan
#   - 43 MAG
#   - 43 Orange
#   - 43 Sour
#
# First 10 Ingredients:
#   - ACE-Saft
#   - Aal
#   - Abalone
#   - Abate
#   - Abbaye Citeaux
#   - Abbaye d'Orval
#   - Abbaye de Chimay
#   - Abbaye de Cîteaux
#   - Abbaye de Floreffe
#   - Abbaye de Maredsous

# %%
import os
for f in os.listdir("kochwiki_data"):
    size = os.path.getsize(f"kochwiki_data/{f}") / (1024*1024)
    print(f"{f}: {size:.1f} MB")
# Out:
# kategorien.json: 0.0 MB
# zubereitungen.json: 1.3 MB
# zutaten_parsed.json: 11.1 MB
# zutaten.json: 4.6 MB
# rezepte.json: 35.3 MB
# rezepte_parsed.json: 99.7 MB
